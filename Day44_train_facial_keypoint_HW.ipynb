# %% [markdown]
# <a href="https://colab.research.google.com/github/crea0414/1st_CVDL/blob/master/Day44_train_facial_keypoint_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My\ Drive/First_CV_DL191125/DataSet/
# Out:
# /content/gdrive/My Drive/First_CV_DL191125/DataSet

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 15s 8ms/step - loss: 0.0121 - val_loss: 0.0039
#
# Epoch 00001: val_loss improved from inf to 0.00391, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0025 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00391 to 0.00198, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00198 to 0.00194, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00194 to 0.00194, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00194 to 0.00186, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00006: val_loss did not improve from 0.00186
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00186 to 0.00185, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00008: val_loss did not improve from 0.00185
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00009: val_loss improved from 0.00185 to 0.00180, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00010: val_loss did not improve from 0.00180
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8991e-04 - val_loss: 0.0017
#
# Epoch 00011: val_loss improved from 0.00180 to 0.00169, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.8527e-04 - val_loss: 0.0015
#
# Epoch 00012: val_loss improved from 0.00169 to 0.00152, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.0807e-04 - val_loss: 0.0014
#
# Epoch 00013: val_loss improved from 0.00152 to 0.00135, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.3264e-04 - val_loss: 0.0013
#
# Epoch 00014: val_loss improved from 0.00135 to 0.00130, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.9789e-04 - val_loss: 0.0012
#
# Epoch 00015: val_loss improved from 0.00130 to 0.00117, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.3863e-04 - val_loss: 0.0011
#
# Epoch 00016: val_loss improved from 0.00117 to 0.00108, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0352e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss improved from 0.00108 to 0.00105, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.6774e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss improved from 0.00105 to 0.00104, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4893e-04 - val_loss: 0.0010
#
# Epoch 00019: val_loss improved from 0.00104 to 0.00103, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.1951e-04 - val_loss: 9.9271e-04
#
# Epoch 00020: val_loss improved from 0.00103 to 0.00099, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.1151e-04 - val_loss: 9.8067e-04
#
# Epoch 00021: val_loss improved from 0.00099 to 0.00098, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9822e-04 - val_loss: 9.2472e-04
#
# Epoch 00022: val_loss improved from 0.00098 to 0.00092, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.8032e-04 - val_loss: 9.0540e-04
#
# Epoch 00023: val_loss improved from 0.00092 to 0.00091, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6075e-04 - val_loss: 9.2304e-04
#
# Epoch 00024: val_loss did not improve from 0.00091
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4954e-04 - val_loss: 8.8964e-04
#
# Epoch 00025: val_loss improved from 0.00091 to 0.00089, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4156e-04 - val_loss: 8.8878e-04
#
# Epoch 00026: val_loss improved from 0.00089 to 0.00089, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2420e-04 - val_loss: 8.6663e-04
#
# Epoch 00027: val_loss improved from 0.00089 to 0.00087, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2082e-04 - val_loss: 8.5807e-04
#
# Epoch 00028: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0838e-04 - val_loss: 8.7796e-04
#
# Epoch 00029: val_loss did not improve from 0.00086
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9959e-04 - val_loss: 8.7833e-04
#
# Epoch 00030: val_loss did not improve from 0.00086
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9496e-04 - val_loss: 9.1204e-04
#
# Epoch 00031: val_loss did not improve from 0.00086
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9265e-04 - val_loss: 8.4995e-04
#
# Epoch 00032: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8265e-04 - val_loss: 8.6716e-04
#
# Epoch 00033: val_loss did not improve from 0.00085
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7665e-04 - val_loss: 8.1816e-04
#
# Epoch 00034: val_loss improved from 0.00085 to 0.00082, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7788e-04 - val_loss: 8.4231e-04
#
# Epoch 00035: val_loss did not improve from 0.00082
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6744e-04 - val_loss: 8.4467e-04
#
# Epoch 00036: val_loss did not improve from 0.00082
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6679e-04 - val_loss: 8.1899e-04
#
# Epoch 00037: val_loss did not improve from 0.00082
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5673e-04 - val_loss: 8.2374e-04
#
# Epoch 00038: val_loss did not improve from 0.00082
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4839e-04 - val_loss: 8.5447e-04
#
# Epoch 00039: val_loss did not improve from 0.00082
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4293e-04 - val_loss: 8.0049e-04
#
# Epoch 00040: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3988e-04 - val_loss: 7.9242e-04
#
# Epoch 00041: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3709e-04 - val_loss: 8.4462e-04
#
# Epoch 00042: val_loss did not improve from 0.00079
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4228e-04 - val_loss: 8.3908e-04
#
# Epoch 00043: val_loss did not improve from 0.00079
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3324e-04 - val_loss: 7.8265e-04
#
# Epoch 00044: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2743e-04 - val_loss: 8.4942e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2515e-04 - val_loss: 8.2011e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1557e-04 - val_loss: 7.8664e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0942e-04 - val_loss: 7.7568e-04
#
# Epoch 00048: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1514e-04 - val_loss: 7.8431e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0749e-04 - val_loss: 8.4055e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0419e-04 - val_loss: 8.0451e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1048e-04 - val_loss: 8.3309e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9935e-04 - val_loss: 7.7352e-04
#
# Epoch 00053: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0248e-04 - val_loss: 8.3353e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9465e-04 - val_loss: 7.7009e-04
#
# Epoch 00055: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9293e-04 - val_loss: 8.2166e-04
#
# Epoch 00056: val_loss did not improve from 0.00077
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9348e-04 - val_loss: 7.5328e-04
#
# Epoch 00057: val_loss improved from 0.00077 to 0.00075, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8640e-04 - val_loss: 7.7734e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8925e-04 - val_loss: 7.8532e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8708e-04 - val_loss: 7.7625e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8026e-04 - val_loss: 7.7441e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7477e-04 - val_loss: 8.2743e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7850e-04 - val_loss: 7.8627e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7444e-04 - val_loss: 7.7305e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7509e-04 - val_loss: 8.3553e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7398e-04 - val_loss: 7.6981e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7306e-04 - val_loss: 8.0277e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6581e-04 - val_loss: 7.7242e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6474e-04 - val_loss: 7.5359e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6807e-04 - val_loss: 7.9762e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6726e-04 - val_loss: 7.7144e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6500e-04 - val_loss: 7.8496e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6444e-04 - val_loss: 7.8923e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6093e-04 - val_loss: 7.4508e-04
#
# Epoch 00074: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6193e-04 - val_loss: 7.5754e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5887e-04 - val_loss: 7.7717e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6046e-04 - val_loss: 7.7993e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6040e-04 - val_loss: 7.7312e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5559e-04 - val_loss: 7.4949e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5270e-04 - val_loss: 8.1778e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5098e-04 - val_loss: 7.8594e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5220e-04 - val_loss: 7.6510e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4974e-04 - val_loss: 7.5342e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4504e-04 - val_loss: 7.9307e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4500e-04 - val_loss: 7.6793e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.4573e-04 - val_loss: 7.5351e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4164e-04 - val_loss: 7.5727e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4132e-04 - val_loss: 8.0183e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4212e-04 - val_loss: 7.7912e-04
#
# Epoch 00089: val_loss did not improve from 0.00075
# Epoch 90/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.4019e-04 - val_loss: 7.8523e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3859e-04 - val_loss: 7.3786e-04
#
# Epoch 00091: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3846e-04 - val_loss: 7.5100e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3632e-04 - val_loss: 7.5485e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3795e-04 - val_loss: 7.4919e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3648e-04 - val_loss: 7.9314e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3521e-04 - val_loss: 7.4923e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3293e-04 - val_loss: 7.6940e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3194e-04 - val_loss: 7.6065e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3122e-04 - val_loss: 7.5578e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2476e-04 - val_loss: 7.5907e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2838e-04 - val_loss: 7.6115e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2812e-04 - val_loss: 7.7742e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.2954e-04 - val_loss: 7.6775e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2751e-04 - val_loss: 7.4807e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2306e-04 - val_loss: 7.6861e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2831e-04 - val_loss: 7.9364e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2839e-04 - val_loss: 7.7817e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.2505e-04 - val_loss: 8.0987e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.1857e-04 - val_loss: 7.7988e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1859e-04 - val_loss: 7.3620e-04
#
# Epoch 00110: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1955e-04 - val_loss: 7.4815e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.2047e-04 - val_loss: 7.6232e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2656e-04 - val_loss: 7.4763e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2027e-04 - val_loss: 7.8758e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1559e-04 - val_loss: 7.5516e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1604e-04 - val_loss: 7.8905e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1588e-04 - val_loss: 7.7712e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1313e-04 - val_loss: 7.4614e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1210e-04 - val_loss: 7.7882e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1424e-04 - val_loss: 8.0225e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1358e-04 - val_loss: 7.8441e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.1100e-04 - val_loss: 7.9234e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1015e-04 - val_loss: 7.5094e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0872e-04 - val_loss: 7.7168e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1144e-04 - val_loss: 7.4513e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0814e-04 - val_loss: 7.6865e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0534e-04 - val_loss: 7.6563e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0531e-04 - val_loss: 7.6928e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0526e-04 - val_loss: 7.5662e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0608e-04 - val_loss: 7.8172e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0867e-04 - val_loss: 8.0031e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0902e-04 - val_loss: 7.6233e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0630e-04 - val_loss: 7.5852e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0242e-04 - val_loss: 7.8778e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.0170e-04 - val_loss: 7.7172e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9580e-05 - val_loss: 7.6962e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0129e-04 - val_loss: 7.6344e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9991e-05 - val_loss: 7.4511e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0208e-04 - val_loss: 7.5897e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0230e-04 - val_loss: 8.1070e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0568e-04 - val_loss: 8.0270e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0069e-04 - val_loss: 7.8012e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0166e-04 - val_loss: 7.9704e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7396e-05 - val_loss: 7.7039e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9381e-05 - val_loss: 7.3800e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0120e-04 - val_loss: 7.5994e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9542e-05 - val_loss: 7.4423e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0178e-04 - val_loss: 7.4858e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3698e-05 - val_loss: 7.8127e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3286e-05 - val_loss: 8.0459e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %%
model_reload = get_model()
model_reload.load_weights('weights.h5')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_reload.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
class Face_horizontal_flip(object):
    def __init__(self, landmark, image):
        self.origin_mark = landmark
        self.h_flip_mark = np.zeros_like(landmark)
        self.origin_image = image
    def __call__(self):
        for idx, mark in enumerate(self.origin_mark):
            if idx%2 ==0:
                self.h_flip_mark[idx] = (-mark)
            else:
                self.h_flip_mark[idx] = mark
        
        return cv2.flip(self.origin_image, 1), self.h_flip_mark

# %%
flip_img, flip_mark = Face_horizontal_flip(points_test[0], imgs_test[0])()
plot_keypoints(flip_img, flip_mark)

# %%
fig = plt.figure(figsize=(15,15))
#points_test = model_reload.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    img_flip, mark_flip = Face_horizontal_flip(points_train[i], imgs_train[i])()
    plot_keypoints(img_flip, mark_flip)
